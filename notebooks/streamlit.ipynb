# %%
import pandas as pd
df=pd.read_csv("../data/cybersecurity_cleaned.csv")

# %%
count = (df["label"]==1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6763    False
# 6764    False
# 6765    False
# 6766    False
# 6767    False
# Name: label, Length: 6768, dtype: bool
