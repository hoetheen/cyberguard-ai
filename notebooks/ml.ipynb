# %%
import pandas as pd
df=pd.read_csv("../data/cybersecurity.csv")

# %%
#maybe no need
df_clean = df.dropna()
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6768 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            6768 non-null   str
#  1   src_ip               6768 non-null   str
#  2   dst_ip               6768 non-null   str
#  3   src_port             6768 non-null   int64
#  4   dst_port             6768 non-null   int64
#  5   protocol             6768 non-null   str
#  6   bytes_sent           6768 non-null   int64
#  7   bytes_received       6768 non-null   int64
#  8   user_agent           6768 non-null   str
#  9   url                  6768 non-null   str
#  10  is_internal_traffic  6768 non-null   bool
#  11  label                6768 non-null   int64
#  12  attack_type          6768 non-null   str
# dtypes: bool(1), int64(5), str(7)
# memory usage: 694.0 KB

# %%
#need dictionary
unique_protocol = df_clean["protocol"].unique().tolist()
unique_protocol_List = []
for item in unique_protocol:
    unique_protocol_List.append(item)
unique_protocol_List
# Out:
# ['TCP', 'UDP', 'ICMP']

# %%
protocol_dict = {}
for item in unique_protocol_List:
    protocol_dict[item] = unique_protocol_List.index(item)
protocol_dict
# Out:
# {'TCP': 0, 'UDP': 1, 'ICMP': 2}

# %%
#to retrieve the numbers
list(protocol_dict.values())
# Out:
# [0, 1, 2]

# %%
from sklearn.ensemble import IsolationForest
model = IsolationForest()
